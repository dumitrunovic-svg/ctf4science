# %% [markdown]
# # Guide: Visualizing and Reading instaseis CTF Data Files
#
# This notebook demonstrates how to read and visualize seismic wavefield data stored in the instaseis CTF format (as .npz files). It also explains how to extract sensor locations and determine the number of sensors (`N_sensors`) directly from the data matrix.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

import plotly.express as px
import plotly.graph_objects as go

from plot_seis_helpers import *

# %% [markdown]
# # From CTF X files

# %%
f1 = Path(os.getcwd()).parent / 'data' / 'seismo' / 'train' / 'X1train.npz'
f2 = Path(os.getcwd()).parent / 'data' / 'seismo' / 'sensor_locations.csv'

verbose=False

#plot_sensor_time_series(f1,f2, 1110, verbose=verbose)
#visualize_wavefield_plotly_scatter(f1,f2, 1110, verbose=verbose)
visualize_wavefield_plotly_scatter_with_slider(f1,f2, 10, verbose=verbose)
#visualize_wavefield_plotly(f1,f2, 1100, verbose=verbose)
#visualize_wavefield_plotly_with_slider(f1,f2, 10, verbose=verbose)
#plot_wavefield_timeseries_heatmap(f1,f2, verbose=verbose)
#plot_wavefield_timeseries_heatmap_with_geography(f1,f2, verbose=verbose)

# %%
#f1 = Path(os.getcwd()).parent / 'models' / 'moirai' / 'pickles' / 'seismo_1.pkl'
#f2 = Path(os.getcwd()).parent / 'data' / 'seismo' / 'sensor_locations.csv'

#plot_sensor_time_series(f1,f2, 600, verbose=verbose)
##visualize_wavefield_plotly(f1,f2, 600, verbose=verbose)
#visualize_wavefield_plotly_with_slider(f1,f2, 10, verbose=verbose)
